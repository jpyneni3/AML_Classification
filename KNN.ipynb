# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.ensemble
import sklearn.preprocessing
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
train_path = 'data/train/'
val_path = 'data/val/'

x_train = pd.read_csv(train_path+'x_train.csv',header=0, index_col=0)
x_train.head()
# Out:
#          FS Lin 1  SS Log 1  FL1 Log 1  FL2 Log 1  FL3 Log 1  FL4 Log 1  \
# 93  -1.238618e-17  0.565956   0.280841   0.223077   0.598613   0.182531
# 156  5.781330e-18  0.568719   0.318037   0.292307   0.623323   0.209472
# 91   1.148340e-17  0.574159   0.234444   0.218705   0.513039   0.185863
# 166 -1.611239e-17  0.509394   0.275858   0.230681   0.624075   0.203419
# 124 -1.732429e-17  0.599630   0.314093   0.282904   0.560655   0.198022
#
#      FL5 Log 1      FS Lin 2  SS Log 2  FL1 Log 2  ...  FL3 Log 7  FL4 Log 7  \
# 93    0.182293  8.003122e-18  0.562951   0.461278  ...   0.597456   0.239223
# 156   0.226009 -1.104593e-17  0.570587   0.414329  ...   0.625819   0.262777
# 91    0.169648 -9.551458e-18  0.576222   0.434044  ...   0.524925   0.214383
# 166   0.186238  4.256647e-18  0.510081   0.485005  ...   0.644491   0.327046
# 124   0.178590  1.371567e-17  0.597674   0.435638  ...   0.559887   0.213564
#
# ...

# %%
y_train = pd.read_csv(train_path+'y_train.csv',header=0, index_col=0)
y_train.head()
# Out:
#      label
# 93       0
# 156      0
# 91       0
# 166      0
# 124      0

# %%
x_val = pd.read_csv(val_path+'x_val.csv',header=0, index_col=0)
x_val.head()
# Out:
#          FS Lin 1  SS Log 1  FL1 Log 1  FL2 Log 1  FL3 Log 1  FL4 Log 1  \
# 163  8.566120e-18  0.551454   0.241192   0.220625   0.516839   0.208294
# 142  1.427886e-17  0.527122   0.277500   0.272824   0.545868   0.192125
# 14   2.579255e-18  0.537403   0.267647   0.230579   0.617686   0.200086
# 45  -7.377681e-18  0.559337   0.219580   0.200886   0.676990   0.192669
# 81  -2.415921e-17  0.591457   0.235514   0.212839   0.546684   0.183770
#
#      FL5 Log 1      FS Lin 2  SS Log 2  FL1 Log 2  ...  FL3 Log 7  FL4 Log 7  \
# 163   0.155872  1.165200e-18  0.552685   0.359967  ...   0.519395   0.237622
# 142   0.163143  2.113693e-17  0.528486   0.409050  ...   0.537398   0.250894
# 14    0.167136 -1.427629e-17  0.538384   0.341642  ...   0.620094   0.261141
# 45    0.169655  2.649278e-17  0.562957   0.327307  ...   0.676566   0.330513
# 81    0.175548 -8.323416e-18  0.597730   0.351928  ...   0.556212   0.199599
#
# ...

# %%
y_val = pd.read_csv(val_path+'y_val.csv',header=0, index_col=0)
y_val.head()
# Out:
#      label
# 163      0
# 142      0
# 14       0
# 45       0
# 81       0

# %%
classifier =  KNeighborsClassifier(n_neighbors=2, weights='distance')
classifier.fit(x_train, y_train.values.ravel())
# Out:
# KNeighborsClassifier(n_neighbors=2, weights='distance')

# %%
#Returns the classifier's accuracy
def accuracy(classifier) -> float:
    num_correct = 0
    for i in range(len(x_val)):
        pred = classifier.predict([x_val.values[i]])[0]
        correct = y_val.values[i]
        if pred == correct:
                num_correct += 1
    return num_correct / len(x_val)

# %%
print(accuracy(classifier))
# Out:
# 0.9166666666666666
